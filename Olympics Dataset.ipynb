# %%
import numpy as np
import pandas as pd

# %%
olm = pd.read_csv('athlete_events.csv')

# %%
olm.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
olm
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
olm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
# ID        271116 non-null int64
# Name      271116 non-null object
# Sex       271116 non-null object
# Age       261642 non-null float64
# Height    210945 non-null float64
# Weight    208241 non-null float64
# Team      271116 non-null object
# NOC       271116 non-null object
# Games     271116 non-null object
# Year      271116 non-null int64
# Season    271116 non-null object
# City      271116 non-null object
# Sport     271116 non-null object
# Event     271116 non-null object
# Medal     39783 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
olm_games = olm[olm['Sport'] == 'Tug Of War']

# %%
olm_games.shape
# Out:
# (0, 15)

# %%
olm_games = olm[olm['Sex'] == 'M']

# %%
olm_games.shape
# Out:
# (196594, 15)

# %%
olm_games = olm[olm['Medal'] == 'Gold']

# %%
olm_games
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 42          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 60          20                   Kjetil Andr Aamodt   M  20.0   176.0    85.0
# ...        ...                                  ...  ..   ...     ...     ...
# 270981  135503                      Zurab Zviadauri   M  23.0   182.0    90.0
# 271009  135520                          Julia Zwehl   F  28.0   167.0    60.0
# 271016  135523       Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0    93.0
# 271049  135545                      Henk Jan Zwolle   M  31.0   197.0    93.0
# 271076  135553  Galina Ivanovna Zybina (-Fyodorova)   F  21.0   168.0    80.0
#
# ...

# %%
olm['Sport'].unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
golf = olm[olm['Sport'] == 'Golf']

# %%
golf
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 283        150        Margaret Ives Abbott (-Dunne)   F  23.0     NaN     NaN
# 284        151  Mary Perkins Ives Abbott (Perkins-)   F  42.0     NaN     NaN
# 1449       806             Bartlett S. "Bart" Adams   M  38.0     NaN     NaN
# 2247      1244                Felipe Aguilar Schler   M  41.0   170.0    72.0
# 4979      2842         Henry Woodward "Harry" Allen   M  27.0     NaN     NaN
# ...        ...                                  ...  ..   ...     ...     ...
# 262799  131494                  Warren Kenneth Wood   M  17.0   178.0     NaN
# 263305  131763                             Wu Ashun   M  31.0   183.0    81.0
# 264705  132465                 Hee-Young "Amy" Yang   F  27.0   173.0    77.0
# 265152  132698                   Meade Walker Yates   M  40.0     NaN     NaN
# 267788  133971           Fabrizio Zanotti Cavazzoni   M  33.0   169.0    70.0
#
# ...

# %%
golf['Medal'].unique()
# Out:
# array(['Gold', nan, 'Bronze', 'Silver'], dtype=object)

# %%
countries_in_golf = golf['NOC'].unique()

# %%
countries_in_golf
# Out:
# array(['USA', 'CHI', 'KOR', 'THA', 'IND', 'CAN', 'ISR', 'ITA', 'FRA',
#        'ESP', 'MEX', 'GER', 'HKG', 'MAS', 'BEL', 'BRA', 'GBR', 'CHN',
#        'NZL', 'AUS', 'ARG', 'POR', 'PAR', 'MAR', 'IRL', 'JPN', 'FIN',
#        'SUI', 'DEN', 'NOR', 'TPE', 'SWE', 'NED', 'GRE', 'BAN', 'RSA',
#        'CZE', 'PHI', 'COL', 'VEN', 'RUS', 'AUT'], dtype=object)

# %%
usa_silver_medalist = golf[(golf['NOC'] == 'USA') & (golf['Medal'] == 'Silver')]
usa_silver_medalist.shape
# Out:
# (12, 15)

# %%
usa_gold_medalist = golf[(golf['NOC'] == 'USA') & (golf['Medal'] == 'Gold')]
usa_gold_medalist.shape
# Out:
# (12, 15)

# %%
usa_bronze_medalist = golf[(golf['NOC'] == 'USA') & (golf['Medal'] == 'Bronze')]
usa_bronze_medalist.shape
# Out:
# (14, 15)

# %%
usa_got_no_medal = golf[(golf['NOC'] == 'USA') & (golf['Medal'] == 'NaN')]
usa_got_no_medal.shape
# Out:
# (0, 15)

# %%
gold_medalist = golf[golf['Medal'] == 'Gold']

# %%
gold_medalist
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 283        150   Margaret Ives Abbott (-Dunne)   F  23.0     NaN     NaN
# 47161    24307  Edward McClellan "Ned" Cummins   M  17.0     NaN     NaN
# 61482    31490     Kenneth Paine "Ken" Edwards   M  18.0     NaN     NaN
# 61609    31544             Henry Chandler Egan   M  19.0     NaN     NaN
# 61613    31547              Walter Eugene Egan   M  23.0   178.0     NaN
# 100999   51069      Robert Edward "Bob" Hunter   M  17.0     NaN     NaN
# 144780   72655             George Seymour Lyon   M  45.0     NaN     NaN
# 162653   81675       Nathaniel Ford Moore, III   M  20.0     NaN     NaN
# 182085   91521                     Park In-Bee   F  28.0   168.0    65.0
# 187886   94405            Mason Elliott Phelps   M  18.0     NaN     NaN
# 204265  102561               Justin Peter Rose   M  36.0   191.0     NaN
# 209892  105390            Charles Edward Sands   M  34.0   181.0     NaN
# ...

# %%
gold_medalist['Medal'].count()
# Out:
# 15

# %%
noc = gold_medalist['NOC'].unique()

# %%
usa = gold_medalist[gold_medalist['NOC'] == 'USA']
usa.shape
# Out:
# (12, 15)

# %%
can = gold_medalist[gold_medalist['NOC'] == 'CAN']
can.shape
# Out:
# (1, 15)

# %%
kor = gold_medalist[gold_medalist['NOC'] == 'KOR']
kor.shape
# Out:
# (1, 15)

# %%
gbr = gold_medalist[gold_medalist['NOC'] == 'GBR']
gbr.shape
# Out:
# (1, 15)

# %%
for i in noc:
    
    print (str(gold_medalist[gold_medalist['NOC']==i].shape)+'   '+ i )
# Out:
# (12, 15)   USA
# (1, 15)   CAN
# (1, 15)   KOR
# (1, 15)   GBR

# %%
usa_medalist = gold_medalist[gold_medalist['NOC'] == 'USA']

# %%
usa_medalist
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 283        150   Margaret Ives Abbott (-Dunne)   F  23.0     NaN     NaN
# 47161    24307  Edward McClellan "Ned" Cummins   M  17.0     NaN     NaN
# 61482    31490     Kenneth Paine "Ken" Edwards   M  18.0     NaN     NaN
# 61609    31544             Henry Chandler Egan   M  19.0     NaN     NaN
# 61613    31547              Walter Eugene Egan   M  23.0   178.0     NaN
# 100999   51069      Robert Edward "Bob" Hunter   M  17.0     NaN     NaN
# 162653   81675       Nathaniel Ford Moore, III   M  20.0     NaN     NaN
# 187886   94405            Mason Elliott Phelps   M  18.0     NaN     NaN
# 209892  105390            Charles Edward Sands   M  34.0   181.0     NaN
# 211810  106350      Daniel Edward "Ned" Sawyer   M  22.0     NaN     NaN
# 223951  112493              Clement Eyer Smoot   M  20.0     NaN     NaN
# 262799  131494             Warren Kenneth Wood   M  17.0   178.0     NaN
#
# ...

# %%
usa_medalist['Event'].unique()
# Out:
# array(["Golf Women's Individual", "Golf Men's Team",
#        "Golf Men's Individual"], dtype=object)

# %%
usa_medalist['Sex'].hist()

# %%
usa_medalist['Sex'].hist(kind = 'bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-4d3fa42cfbf9> in <module>()
# ----> 1 usa_medalist['Sex'].hist(kind = 'bar')
#
# ~\Anaconda3.7\lib\site-packages\pandas\plotting\_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#      83         figsize=figsize,
#      84         bins=bins,
# ---> 85         **kwds
#      86     )
#      87
#
# ~\Anaconda3.7\lib\site-packages\pandas\plotting\_matplotlib\hist.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#     314         values = self.dropna().values
#     315
# --> 316         ax.hist(values, bins=bins, **kwds)
#     317         ax.grid(grid)
#     318         axes = np.array([ax])
#
# ~\Anaconda3.7\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
usa_medalist['Name'].count()
# Out:
# 12

# %%
female_usa_medalist = usa_medalist[usa_medalist['Sex'] == 'F']

# %%
female_usa_medalist
# Out:
#       ID                           Name Sex   Age  Height  Weight  \
# 283  150  Margaret Ives Abbott (-Dunne)   F  23.0     NaN     NaN
#
#               Team  NOC        Games  Year  Season   City Sport  \
# 283  United States  USA  1900 Summer  1900  Summer  Paris  Golf
#
#                        Event Medal
# 283  Golf Women's Individual  Gold

# %%
male_usa_medalist = usa_medalist[usa_medalist['Sex'] == 'M']
male_usa_medalist
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 47161    24307  Edward McClellan "Ned" Cummins   M  17.0     NaN     NaN
# 61482    31490     Kenneth Paine "Ken" Edwards   M  18.0     NaN     NaN
# 61609    31544             Henry Chandler Egan   M  19.0     NaN     NaN
# 61613    31547              Walter Eugene Egan   M  23.0   178.0     NaN
# 100999   51069      Robert Edward "Bob" Hunter   M  17.0     NaN     NaN
# 162653   81675       Nathaniel Ford Moore, III   M  20.0     NaN     NaN
# 187886   94405            Mason Elliott Phelps   M  18.0     NaN     NaN
# 209892  105390            Charles Edward Sands   M  34.0   181.0     NaN
# 211810  106350      Daniel Edward "Ned" Sawyer   M  22.0     NaN     NaN
# 223951  112493              Clement Eyer Smoot   M  20.0     NaN     NaN
# 262799  131494             Warren Kenneth Wood   M  17.0   178.0     NaN
#
#                               Team  NOC        Games  Year  Season       City  \
# ...

# %%
male_usa_medalist['Team'].unique()
# Out:
# array(['Western Golf Association-1', 'United States'], dtype=object)

# %%
male_usa_medalist['Year'].unique()
# Out:
# array([1904, 1900], dtype=int64)

# %%
male_usa_medalist['Age'].hist()
